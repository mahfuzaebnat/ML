# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
dataset = pd.read_csv('wholesale-trade-survey-dec-2021-quarter-csv.csv')

# %%
dataset
# Out:
#      Series_reference   Period  Data_value  Suppressed STATUS    UNITS  \
# 0         WTSQ.SFA1CA  1995.03    2368.690         NaN      F  Dollars
# 1         WTSQ.SFA1CA  1995.06    2100.440         NaN      F  Dollars
# 2         WTSQ.SFA1CA  1995.09    2070.210         NaN      F  Dollars
# 3         WTSQ.SFA1CA  1995.12    2284.770         NaN      F  Dollars
# 4         WTSQ.SFA1CA  1996.03    2134.760         NaN      F  Dollars
# ...               ...      ...         ...         ...    ...      ...
# 4953      WTSQ.SFZ9CT  2020.12   12250.151         NaN      R  Dollars
# 4954      WTSQ.SFZ9CT  2021.03   12478.036         NaN      R  Dollars
# 4955      WTSQ.SFZ9CT  2021.06   13000.545         NaN      R  Dollars
# 4956      WTSQ.SFZ9CT  2021.09   13652.738         NaN      R  Dollars
# 4957      WTSQ.SFZ9CT  2021.12   14286.723         NaN      F  Dollars
#
#       Magnitude                       Subject  \
# 0             6  Wholesale Trade Survey - WTS
# ...

# %%
dataset.head()
# Out:
#   Series_reference   Period  Data_value  Suppressed STATUS    UNITS  \
# 0      WTSQ.SFA1CA  1995.03     2368.69         NaN      F  Dollars
# 1      WTSQ.SFA1CA  1995.06     2100.44         NaN      F  Dollars
# 2      WTSQ.SFA1CA  1995.09     2070.21         NaN      F  Dollars
# 3      WTSQ.SFA1CA  1995.12     2284.77         NaN      F  Dollars
# 4      WTSQ.SFA1CA  1996.03     2134.76         NaN      F  Dollars
#
#    Magnitude                       Subject  \
# 0          6  Wholesale Trade Survey - WTS
# 1          6  Wholesale Trade Survey - WTS
# 2          6  Wholesale Trade Survey - WTS
# 3          6  Wholesale Trade Survey - WTS
# 4          6  Wholesale Trade Survey - WTS
#
#                                                Group  \
# 0  Industry by variable - (ANZSIC06) - Subannual ...
# 1  Industry by variable - (ANZSIC06) - Subannual ...
# 2  Industry by variable - (ANZSIC06) - Subannual ...
# 3  Industry by variable - (ANZSIC06) - Subannual ...
# ...

# %%
dataset.head(10)
# Out:
#   Series_reference   Period  Data_value  Suppressed STATUS    UNITS  \
# 0      WTSQ.SFA1CA  1995.03     2368.69         NaN      F  Dollars
# 1      WTSQ.SFA1CA  1995.06     2100.44         NaN      F  Dollars
# 2      WTSQ.SFA1CA  1995.09     2070.21         NaN      F  Dollars
# 3      WTSQ.SFA1CA  1995.12     2284.77         NaN      F  Dollars
# 4      WTSQ.SFA1CA  1996.03     2134.76         NaN      F  Dollars
# 5      WTSQ.SFA1CA  1996.06     2038.45         NaN      F  Dollars
# 6      WTSQ.SFA1CA  1996.09     2031.17         NaN      F  Dollars
# 7      WTSQ.SFA1CA  1996.12     2263.97         NaN      F  Dollars
# 8      WTSQ.SFA1CA  1997.03     1997.05         NaN      F  Dollars
# 9      WTSQ.SFA1CA  1997.06     2025.13         NaN      F  Dollars
#
#    Magnitude                       Subject  \
# 0          6  Wholesale Trade Survey - WTS
# 1          6  Wholesale Trade Survey - WTS
# 2          6  Wholesale Trade Survey - WTS
# ...

# %%
dataset.head(3)
# Out:
#   Series_reference   Period  Data_value  Suppressed STATUS    UNITS  \
# 0      WTSQ.SFA1CA  1995.03     2368.69         NaN      F  Dollars
# 1      WTSQ.SFA1CA  1995.06     2100.44         NaN      F  Dollars
# 2      WTSQ.SFA1CA  1995.09     2070.21         NaN      F  Dollars
#
#    Magnitude                       Subject  \
# 0          6  Wholesale Trade Survey - WTS
# 1          6  Wholesale Trade Survey - WTS
# 2          6  Wholesale Trade Survey - WTS
#
#                                                Group  \
# 0  Industry by variable - (ANZSIC06) - Subannual ...
# 1  Industry by variable - (ANZSIC06) - Subannual ...
# 2  Industry by variable - (ANZSIC06) - Subannual ...
#
#                Series_title_1            Series_title_2  Series_title_3  \
# 0  Basic material wholesaling  Sales (operating income)  Current prices
# 1  Basic material wholesaling  Sales (operating income)  Current prices
# 2  Basic material wholesaling  Sales (operating income)  Current prices
#
# ...

# %%
dataset.shape
# Out:
# (4958, 14)

# %%
dataset.isnull().any()
# Out:
# Series_reference    False
# Period              False
# Data_value           True
# Suppressed           True
# STATUS              False
# UNITS               False
# Magnitude           False
# Subject             False
# Group               False
# Series_title_1      False
# Series_title_2      False
# Series_title_3      False
# Series_title_4      False
# Series_title_5       True
# dtype: bool

# %%
dataset.isnull().sum()
# Out:
# Series_reference       0
# Period                 0
# Data_value            42
# Suppressed          4958
# STATUS                 0
# UNITS                  0
# Magnitude              0
# Subject                0
# Group                  0
# Series_title_1         0
# Series_title_2         0
# Series_title_3         0
# Series_title_4         0
# Series_title_5      4536
# dtype: int64

# %%
x = dataset[['Period']]
y = dataset[['Data_value']]

# %%
x
# Out:
#        Period
# 0     1995.03
# 1     1995.06
# 2     1995.09
# 3     1995.12
# 4     1996.03
# ...       ...
# 4953  2020.12
# 4954  2021.03
# 4955  2021.06
# 4956  2021.09
# 4957  2021.12
#
# [4958 rows x 1 columns]

# %%
y
# Out:
#       Data_value
# 0       2368.690
# 1       2100.440
# 2       2070.210
# 3       2284.770
# 4       2134.760
# ...          ...
# 4953   12250.151
# 4954   12478.036
# 4955   13000.545
# 4956   13652.738
# 4957   14286.723
#
# [4958 rows x 1 columns]

# %% [markdown]
# # visualization

# %%
plt.scatter(dataset['Period'],dataset['Data_value'])

# %%
plt.scatter(dataset['Period'],dataset['Data_value'])
plt.xlabel('Period')
plt.ylabel('Data_value')
# Out:
# Text(0, 0.5, 'Data_value')

# %%
plt.scatter(dataset['Period'],dataset['Data_value'], marker= '+', color = 'red')
plt.xlabel('Period')
plt.ylabel('Data_value')
plt.title('wholesale-trade-survey-dec-2021')
# Out:
# Text(0.5, 1.0, 'wholesale-trade-survey-dec-2021')
